# %%
import pandas as pd
import numpy as np
import requests
import urllib
import json

# %%
link = "https://coronavirus.data.gov.uk/downloads/csv/coronavirus-cases_latest.csv"

# %%
x = requests.get("https://coronavirus.data.gov.uk/downloads/csv/coronavirus-cases_latest.csv")

# %%
f = urllib.urlopen(link)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-952c2b0797b4> in <module>
# ----> 1 f = urllib.urlopen(link)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
text = x.text
text_file = open('text_file.txt', 'w')
text_file.write(x.text)
text_file.close
# Out:
# <function TextIOWrapper.close()>

# %%
df_data = pd.read_csv('text_file.txt')

# %%
df_data.head()
# Out:
#          Area name  Area code Area type Specimen date  \
# 0          England  E92000001    Nation    2020-05-10
# 1       South West  E12000009    Region    2020-05-10
# 2       South East  E12000008    Region    2020-05-10
# 3           London  E12000007    Region    2020-05-10
# 4  East of England  E12000006    Region    2020-05-10
#
#    Daily lab-confirmed cases  Previously reported daily cases  \
# 0                       58.0                              0.0
# 1                        4.0                              NaN
# 2                        6.0                              NaN
# 3                        0.0                              NaN
# 4                        0.0                              NaN
#
#    Change in daily cases  Cumulative lab-confirmed cases  \
# 0                   58.0                          136873
# 1                    NaN                            7044
# 2                    NaN                           19344
# 3                    NaN                           25891
# 4                    NaN                           12295
#
#    Previously reported cumulative cases  Change in cumulative cases
# 0                              135982.0                       891.0
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26663 entries, 0 to 26662
# Data columns (total 10 columns):
# Area name                               26663 non-null object
# Area code                               26663 non-null object
# Area type                               26663 non-null object
# Specimen date                           26663 non-null object
# Daily lab-confirmed cases               26659 non-null float64
# Previously reported daily cases         92 non-null float64
# Change in daily cases                   92 non-null float64
# Cumulative lab-confirmed cases          26663 non-null int64
# Previously reported cumulative cases    92 non-null float64
# Change in cumulative cases              92 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 2.0+ MB

# %%
df_codes = pd.read_csv('england_codes.csv')

# %%
df_codes.head()
# Out:
#      LAD13CD LAD13CDO               LAD13NM NUTS315CD  \
# 0  E06000001     00EB            Hartlepool     UKC11
# 1  E06000002     00EC         Middlesbrough     UKC12
# 2  E06000003     00EE  Redcar and Cleveland     UKC12
# 3  E06000004     00EF      Stockton-on-Tees     UKC11
# 4  E06000005     00EH            Darlington     UKC13
#
#                          NUTS315NM NUTS215CD               NUTS215NM NUT115CD  \
# 0  Hartlepool and Stockton-on-Tees      UKC1  Tees Valley and Durham      UKC
# 1                   South Teesside      UKC1  Tees Valley and Durham      UKC
# 2                   South Teesside      UKC1  Tees Valley and Durham      UKC
# 3  Hartlepool and Stockton-on-Tees      UKC1  Tees Valley and Durham      UKC
# 4                       Darlington      UKC1  Tees Valley and Durham      UKC
#
#               NUTS115NM  FID
# 0  North East (England)    1
# 1  North East (England)    2
# 2  North East (England)    3
# 3  North East (England)    4
# 4  North East (England)    5

# %%
code_list = df_codes['LAD13CD'].tolist()

# %%
code_list
# Out:
# ['E06000001',
#  'E06000002',
#  'E06000003',
#  'E06000004',
#  'E06000005',
#  'E06000006',
#  'E06000007',
#  'E06000008',
#  'E06000009',
#  'E06000010',
#  'E06000011',
#  'E06000012',
#  'E06000013',
#  'E06000014',
#  'E06000015',
#  'E06000016',
#  'E06000017',
#  'E06000018',
#  'E06000019',
#  'E06000020',
#  'E06000021',
#  'E06000022',
#  'E06000023',
#  'E06000024',
#  'E06000025',
#  'E06000026',
#  'E06000027',
#  'E06000028',
#  'E06000029',
#  'E06000030',
#  'E06000031',
#  'E07000203',
#  'E07000204',
#  'E07000205',
#  'E07000206',
#  'E07000207',
#  'E07000208',
#  'E07000209',
#  'E07000210',
#  'E07000211',
#  'E07000212',
#  'E07000213',
#  'E07000214',
#  'E07000215',
#  'E07000216',
#  'E07000217',
#  'E07000218',
#  'E07000219',
#  'E07000220',
#  'E07000221',
#  'E07000222',
#  'E07000223',
#  'E07000224',
#  'E07000225',
#  'E07000226',
#  'E07000227',
#  'E07000228',
#  'E07000229',
#  'E07000234',
#  'E07000235',
#  'E07000236',
#  'E07000237',
#  'E07000238',
#  'E07000239',
#  'E07000240',
#  'E07000241',
#  'E07000242',
#  'E07000243',
#  'E08000001',
#  'E08000002',
#  'E08000003',
#  'E08000004',
#  'E08000005',
#  'E08000006',
#  'E08000007',
#  'E08000008',
#  'E08000009',
#  'E08000010',
#  'E08000011',
#  'E08000012',
#  'E08000013',
#  'E08000014',
#  'E08000015',
#  'E08000016',
#  'E08000017',
#  'E08000018',
#  'E08000019',
#  'E08000021',
#  'E08000022',
#  'E08000023',
#  'E08000024',
#  'E08000025',
#  'E08000026',
#  'E08000027',
#  'E08000028',
#  'E08000029',
#  'E08000030',
#  'E08000031',
#  'E08000032',
#  'E08000033',
#  'E08000034',
#  'E08000035',
#  'E08000036',
#  'E08000037',
#  'E09000001',
#  'E09000002',
#  'E09000003',
#  'E09000004',
#  'E09000005',
#  'E09000006',
#  'E09000007',
#  'E09000008',
#  'E09000009',
#  'E09000010',
#  'E09000011',
#  'E09000012',
#  'E09000013',
#  'E09000014',
#  'E09000015',
#  'E09000016',
#  'E09000017',
#  'E09000018',
#  'E09000019',
#  'E09000020',
#  'E09000021',
#  'E09000022',
#  'E09000023',
#  'E09000024',
#  'E09000025',
#  'E09000026',
#  'E09000027',
#  'E09000028',
#  'E09000029',
#  'E09000030',
#  'E09000031',
#  'E09000032',
#  'E09000033']

# %%
def get_area_data(df, area_code):
    
    df = df.set_index('Area code')
    if area_code in df.index:
        df_area = df.loc[area_code]
        df_area_row = df_area[:1]
        df_area_row = df_area.loc[:,['Area name', 'Cumulative lab-confirmed cases']]
        df_area_row = df_area_row[:1]
        df_area_row.reset_index(inplace=True)
        return df_area_row.iloc[0,:]

# %%
df_area = get_area_data(df_data, "E06000030")
df_area
# Out:
# Area code                         E06000030
# Area name                           Swindon
# Cumulative lab-confirmed cases          410
# Name: 0, dtype: object

# %%
def get_all_eng_data(df, code_list):
    
    # Initialise main dataframe
    col_names = ['Area code', 'Area name', 'Cumulative lab-confirmed cases']
    my_df = pd.DataFrame(columns = col_names)
    
    for code in code_list:
        
        my_df.loc[len(my_df)] = get_area_data(df_data, code)
        
    my_df = my_df.set_index('Area code')
    my_df = my_df.dropna()
    return my_df

# %%
df_england_data = get_all_eng_data(df_data, code_list)

# %%
df_england_data.to_json('eng_data.json')

# %%
df_data
# Out:
#                       Area name  Area code                   Area type  \
# 0                       England  E92000001                      Nation
# 1                    South West  E12000009                      Region
# 2                    South East  E12000008                      Region
# 3                        London  E12000007                      Region
# 4               East of England  E12000006                      Region
# ...                         ...        ...                         ...
# 26658           Tunbridge Wells  E07000116  Lower tier local authority
# 26659                   England  E92000001                      Nation
# 26660  Yorkshire and The Humber  E12000003                      Region
# 26661                      York  E06000014  Upper tier local authority
# 26662                      York  E06000014  Lower tier local authority
#
#       Specimen date  Daily lab-confirmed cases  \
# 0        2020-05-10                       58.0
# 1        2020-05-10                        4.0
# 2        2020-05-10                        6.0
# 3        2020-05-10                        0.0
# 4        2020-05-10                        0.0
# ...             ...                        ...
# 26658    2020-01-31                        1.0
# 26659    2020-01-30                        1.0
# 26660    2020-01-30                        1.0
# 26661    2020-01-30                        1.0
# 26662    2020-01-30                        1.0
#
#        Previously reported daily cases  Change in daily cases  \
# 0                                  0.0                   58.0
# 1                                  NaN                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
# ...                                ...                    ...
# 26658                              NaN                    NaN
# 26659                              1.0                    0.0
# 26660                              NaN                    NaN
# 26661                              NaN                    NaN
# 26662                              NaN                    NaN
#
#        Cumulative lab-confirmed cases  Previously reported cumulative cases  \
# 0                              136873                              135982.0
# 1                                7044                                   NaN
# 2                               19344                                   NaN
# 3                               25891                                   NaN
# 4                               12295                                   NaN
# ...                               ...                                   ...
# 26658                               1                                   NaN
# 26659                               1                                   1.0
# 26660                               1                                   NaN
# 26661                               1                                   NaN
# 26662                               1                                   NaN
#
#        Change in cumulative cases
# 0                           891.0
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 26658                         NaN
# 26659                         0.0
# 26660                         NaN
# 26661                         NaN
# 26662                         NaN
#
# [26663 rows x 10 columns]

# %%
def get_area_data_chart(df, area_code):
    
    df = df.set_index('Area code')
    if area_code in df.index:
        df_area = df.loc[area_code]
        df_area = df_area.loc[:,['Area name', 'Specimen date', 'Cumulative lab-confirmed cases']]
        df_area = df_area.drop_duplicates()
        df_area = df_area.drop(columns=['Area name'])
        df_area = df_area.rename(columns={'Specimen date':'date', "Cumulative lab-confirmed cases":'value'})
        #df_area_row = df_area_row[:1]
        #df_area_row.reset_index(inplace=True)
        return df_area[::-1]

# %%
df_example = get_area_data_chart(df_data, "E06000043").drop_duplicates()

# %%
df_example.to_csv('test_england_line2.csv')

# %%
df_example
# Out:
#                  date  value
# Area code
# E06000043  2020-02-05      1
# E06000043  2020-02-08      4
# E06000043  2020-02-09      5
# E06000043  2020-03-04      6
# E06000043  2020-03-07      7
# E06000043  2020-03-10      9
# E06000043  2020-03-13     11
# E06000043  2020-03-15     13
# E06000043  2020-03-16     15
# E06000043  2020-03-18     19
# E06000043  2020-03-19     21
# E06000043  2020-03-20     24
# E06000043  2020-03-21     27
# E06000043  2020-03-22     30
# E06000043  2020-03-23     34
# E06000043  2020-03-24     41
# E06000043  2020-03-25     47
# E06000043  2020-03-26     56
# E06000043  2020-03-27     68
# E06000043  2020-03-28     76
# E06000043  2020-03-29     85
# E06000043  2020-03-30     91
# E06000043  2020-03-31     97
# E06000043  2020-04-01    116
# E06000043  2020-04-02    128
# E06000043  2020-04-03    139
# E06000043  2020-04-04    152
# E06000043  2020-04-05    163
# E06000043  2020-04-06    173
# E06000043  2020-04-07    189
# E06000043  2020-04-08    208
# E06000043  2020-04-09    214
# E06000043  2020-04-10    225
# E06000043  2020-04-11    233
# E06000043  2020-04-12    244
# E06000043  2020-04-13    253
# E06000043  2020-04-14    266
# E06000043  2020-04-15    281
# E06000043  2020-04-16    292
# E06000043  2020-04-17    307
# E06000043  2020-04-18    319
# E06000043  2020-04-19    327
# E06000043  2020-04-20    335
# E06000043  2020-04-21    342
# E06000043  2020-04-22    343
# E06000043  2020-04-23    348
# E06000043  2020-04-24    350
# E06000043  2020-04-25    354
# E06000043  2020-04-26    358
# E06000043  2020-04-27    359
# E06000043  2020-04-28    371
# E06000043  2020-04-29    376
# E06000043  2020-04-30    380
# E06000043  2020-05-01    386
# E06000043  2020-05-03    388
# E06000043  2020-05-04    392
# E06000043  2020-05-05    400
# E06000043  2020-05-10    400
